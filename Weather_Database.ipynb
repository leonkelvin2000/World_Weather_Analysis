# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and long itude combinations
lats= np.random.uniform(low = -90.000, high = 90.000, size=2000)
lngs= np.random.uniform(low = -180.000, high = 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Added Citipy dependency

from citipy import citipy

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the citis list.
    
    if city not in cities:
        cities.append(city)
        
# Print the city to confirm sufficent count.

len(cities)
# Out:
# 751

# %%
# Import the requests library

import requests

# Import the API key

from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datatime module from the datatime library

import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.

city_data =[]

# Print the beginning of the logging.

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | tshela
# Processing Record 6 of Set 1 | peniche
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | brownsville
# Processing Record 9 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | pyu
# Processing Record 13 of Set 1 | ketchikan
# Processing Record 14 of Set 1 | ust-maya
# Processing Record 15 of Set 1 | nueva armenia
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | sao filipe
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | makakilo city
# Processing Record 20 of Set 1 | otanche
# Processing Record 21 of Set 1 | sao joao da barra
# Processing Record 22 of Set 1 | cidreira
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | yatou
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | goundam
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | bria
# Processing Record 36 of Set 1 | sinnamary
# Processing Record 37 of Set 1 | emerald
# Processing Record 38 of Set 1 | calvinia
# Processing Record 39 of Set 1 | moose factory
# Processing Record 40 of Set 1 | sofiysk
# City not found. Skipping...
# Processing Record 41 of Set 1 | trapani
# Processing Record 42 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 1 | phan thiet
# Processing Record 44 of Set 1 | egvekinot
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | evensk
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | kurumkan
# Processing Record 49 of Set 1 | salekhard
# Processing Record 50 of Set 1 | cotonou
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 2 | ust-nera
# Processing Record 4 of Set 2 | vila franca do campo
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | ahipara
# Processing Record 8 of Set 2 | rincon
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | alofi
# Processing Record 11 of Set 2 | bose
# Processing Record 12 of Set 2 | comodoro rivadavia
# Processing Record 13 of Set 2 | lorengau
# Processing Record 14 of Set 2 | bumba
# Processing Record 15 of Set 2 | hay river
# Processing Record 16 of Set 2 | clyde river
# Processing Record 17 of Set 2 | isangel
# Processing Record 18 of Set 2 | vila velha
# Processing Record 19 of Set 2 | hithadhoo
# Processing Record 20 of Set 2 | sinjah
# City not found. Skipping...
# Processing Record 21 of Set 2 | selishche
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 26 of Set 2 | chuy
# Processing Record 27 of Set 2 | paamiut
# Processing Record 28 of Set 2 | kruisfontein
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | puerto ayacucho
# Processing Record 31 of Set 2 | bandarbeyla
# Processing Record 32 of Set 2 | katsuura
# Processing Record 33 of Set 2 | le vauclin
# Processing Record 34 of Set 2 | kiunga
# Processing Record 35 of Set 2 | punta arenas
# Processing Record 36 of Set 2 | tahta
# Processing Record 37 of Set 2 | muleba
# Processing Record 38 of Set 2 | santiago
# Processing Record 39 of Set 2 | verrettes
# Processing Record 40 of Set 2 | kimbe
# Processing Record 41 of Set 2 | pospelikha
# Processing Record 42 of Set 2 | tiksi
# Processing Record 43 of Set 2 | port alfred
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | narbonne
# Processing Record 46 of Set 2 | progreso
# Processing Record 47 of Set 2 | aromashevo
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | hirara
# Processing Record 50 of Set 2 | bethel
# Processing Record 1 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 2 of Set 3 | ushuaia
# Processing Record 3 of Set 3 | ilulissat
# Processing Record 4 of Set 3 | puerto escondido
# Processing Record 5 of Set 3 | touros
# Processing Record 6 of Set 3 | alexandria
# Processing Record 7 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 3 | puerto madero
# Processing Record 9 of Set 3 | neiafu
# Processing Record 10 of Set 3 | leningradskiy
# Processing Record 11 of Set 3 | yellowknife
# Processing Record 12 of Set 3 | kodiak
# Processing Record 13 of Set 3 | kondinskoye
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | aksu
# Processing Record 16 of Set 3 | salihorsk
# Processing Record 17 of Set 3 | mae sot
# Processing Record 18 of Set 3 | saint-philippe
# Processing Record 19 of Set 3 | ola
# Processing Record 20 of Set 3 | bartica
# Processing Record 21 of Set 3 | kainantu
# Processing Record 22 of Set 3 | iranshahr
# Processing Record 23 of Set 3 | saulkrasti
# Processing Record 24 of Set 3 | ocampo
# Processing Record 25 of Set 3 | sibut
# Processing Record 26 of Set 3 | beringovskiy
# Processing Record 27 of Set 3 | khatanga
# Processing Record 28 of Set 3 | caravelas
# Processing Record 29 of Set 3 | tukrah
# Processing Record 30 of Set 3 | moron
# Processing Record 31 of Set 3 | volginskiy
# City not found. Skipping...
# Processing Record 32 of Set 3 | port hedland
# Processing Record 33 of Set 3 | shache
# Processing Record 34 of Set 3 | lompoc
# Processing Record 35 of Set 3 | kamenka
# Processing Record 36 of Set 3 | charyshskoye
# Processing Record 37 of Set 3 | itarema
# Processing Record 38 of Set 3 | dabat
# Processing Record 39 of Set 3 | yulara
# Processing Record 40 of Set 3 | kavieng
# Processing Record 41 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 3 | namibe
# Processing Record 43 of Set 3 | scarborough
# Processing Record 44 of Set 3 | saldanha
# Processing Record 45 of Set 3 | el astillero
# Processing Record 46 of Set 3 | balykshi
# Processing Record 47 of Set 3 | albanel
# Processing Record 48 of Set 3 | qaanaaq
# Processing Record 49 of Set 3 | jieshi
# Processing Record 50 of Set 3 | kieta
# Processing Record 1 of Set 4 | hasaki
# Processing Record 2 of Set 4 | dembi dolo
# Processing Record 3 of Set 4 | mitu
# Processing Record 4 of Set 4 | dzaoudzi
# Processing Record 5 of Set 4 | minab
# Processing Record 6 of Set 4 | dzerzhinskoye
# Processing Record 7 of Set 4 | rawson
# Processing Record 8 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 4 | dingle
# Processing Record 10 of Set 4 | geraldton
# Processing Record 11 of Set 4 | tessalit
# Processing Record 12 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 4 | dori
# Processing Record 14 of Set 4 | ribeira grande
# Processing Record 15 of Set 4 | knysna
# Processing Record 16 of Set 4 | upernavik
# Processing Record 17 of Set 4 | tyup
# Processing Record 18 of Set 4 | gizo
# Processing Record 19 of Set 4 | college
# Processing Record 20 of Set 4 | naliya
# Processing Record 21 of Set 4 | castro
# Processing Record 22 of Set 4 | guerrero negro
# Processing Record 23 of Set 4 | ondjiva
# Processing Record 24 of Set 4 | ancud
# Processing Record 25 of Set 4 | riyaq
# City not found. Skipping...
# Processing Record 26 of Set 4 | bengkulu
# Processing Record 27 of Set 4 | iqaluit
# Processing Record 28 of Set 4 | necochea
# Processing Record 29 of Set 4 | pevek
# Processing Record 30 of Set 4 | teshie
# Processing Record 31 of Set 4 | mandawar
# Processing Record 32 of Set 4 | talnakh
# Processing Record 33 of Set 4 | george town
# Processing Record 34 of Set 4 | narsaq
# Processing Record 35 of Set 4 | mezen
# Processing Record 36 of Set 4 | arlit
# Processing Record 37 of Set 4 | tashara
# Processing Record 38 of Set 4 | zhigansk
# Processing Record 39 of Set 4 | severo-kurilsk
# Processing Record 40 of Set 4 | bathsheba
# Processing Record 41 of Set 4 | lazaro cardenas
# Processing Record 42 of Set 4 | sayyan
# Processing Record 43 of Set 4 | cayenne
# Processing Record 44 of Set 4 | provideniya
# Processing Record 45 of Set 4 | japura
# Processing Record 46 of Set 4 | akyab
# Processing Record 47 of Set 4 | bontang
# Processing Record 48 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 4 | avera
# Processing Record 50 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 5 | pangnirtung
# Processing Record 2 of Set 5 | dikson
# Processing Record 3 of Set 5 | longyearbyen
# Processing Record 4 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 5 | cheremnoye
# Processing Record 6 of Set 5 | novouzensk
# Processing Record 7 of Set 5 | mount gambier
# Processing Record 8 of Set 5 | thinadhoo
# Processing Record 9 of Set 5 | camacha
# Processing Record 10 of Set 5 | lefka
# Processing Record 11 of Set 5 | cerrito
# Processing Record 12 of Set 5 | laguna
# Processing Record 13 of Set 5 | beckley
# Processing Record 14 of Set 5 | den helder
# Processing Record 15 of Set 5 | ferme-neuve
# Processing Record 16 of Set 5 | brigantine
# Processing Record 17 of Set 5 | codrington
# Processing Record 18 of Set 5 | viransehir
# Processing Record 19 of Set 5 | banjarmasin
# Processing Record 20 of Set 5 | patacamaya
# Processing Record 21 of Set 5 | dmytrivka
# Processing Record 22 of Set 5 | ipora
# Processing Record 23 of Set 5 | padang
# Processing Record 24 of Set 5 | menongue
# Processing Record 25 of Set 5 | souillac
# Processing Record 26 of Set 5 | sioux lookout
# Processing Record 27 of Set 5 | galesong
# Processing Record 28 of Set 5 | norman wells
# Processing Record 29 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 5 | singaraja
# Processing Record 31 of Set 5 | port blair
# Processing Record 32 of Set 5 | sitka
# Processing Record 33 of Set 5 | xai-xai
# Processing Record 34 of Set 5 | ushtobe
# Processing Record 35 of Set 5 | nanortalik
# Processing Record 36 of Set 5 | saskylakh
# Processing Record 37 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 5 | iberia
# Processing Record 39 of Set 5 | cam ranh
# Processing Record 40 of Set 5 | constantine
# Processing Record 41 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 5 | khani
# Processing Record 43 of Set 5 | luderitz
# Processing Record 44 of Set 5 | safaga
# Processing Record 45 of Set 5 | golyshmanovo
# Processing Record 46 of Set 5 | cay
# Processing Record 47 of Set 5 | coahuayana
# Processing Record 48 of Set 5 | grindavik
# Processing Record 49 of Set 5 | kapit
# Processing Record 50 of Set 5 | manicore
# Processing Record 1 of Set 6 | jacareacanga
# Processing Record 2 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 6 | mokhsogollokh
# Processing Record 4 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 6 | airai
# Processing Record 6 of Set 6 | loiza
# Processing Record 7 of Set 6 | nelson bay
# Processing Record 8 of Set 6 | cap malheureux
# Processing Record 9 of Set 6 | tallahassee
# Processing Record 10 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 6 | dera ghazi khan
# Processing Record 12 of Set 6 | chenghai
# Processing Record 13 of Set 6 | marawi
# Processing Record 14 of Set 6 | hami
# Processing Record 15 of Set 6 | ormara
# Processing Record 16 of Set 6 | kouqian
# Processing Record 17 of Set 6 | malanje
# Processing Record 18 of Set 6 | kamaishi
# Processing Record 19 of Set 6 | qujing
# Processing Record 20 of Set 6 | praya
# Processing Record 21 of Set 6 | panama city
# Processing Record 22 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 6 | valparaiso
# Processing Record 24 of Set 6 | maniitsoq
# Processing Record 25 of Set 6 | tromso
# Processing Record 26 of Set 6 | kuala terengganu
# Processing Record 27 of Set 6 | tura
# Processing Record 28 of Set 6 | zamboanguita
# Processing Record 29 of Set 6 | portland
# Processing Record 30 of Set 6 | najran
# Processing Record 31 of Set 6 | viedma
# Processing Record 32 of Set 6 | taoudenni
# Processing Record 33 of Set 6 | dothan
# Processing Record 34 of Set 6 | port hardy
# Processing Record 35 of Set 6 | port lincoln
# Processing Record 36 of Set 6 | ayan
# Processing Record 37 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 6 | yuzhno-kurilsk
# Processing Record 39 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 6 | bengkalis
# City not found. Skipping...
# Processing Record 41 of Set 6 | hun
# Processing Record 42 of Set 6 | auch
# Processing Record 43 of Set 6 | riyadh
# Processing Record 44 of Set 6 | nouadhibou
# Processing Record 45 of Set 6 | san quintin
# Processing Record 46 of Set 6 | novyye burasy
# Processing Record 47 of Set 6 | carnarvon
# Processing Record 48 of Set 6 | cherskiy
# Processing Record 49 of Set 6 | fortuna
# Processing Record 50 of Set 6 | margate
# Processing Record 1 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 7 | sola
# Processing Record 3 of Set 7 | ituiutaba
# Processing Record 4 of Set 7 | cravo norte
# Processing Record 5 of Set 7 | victoria
# Processing Record 6 of Set 7 | natal
# Processing Record 7 of Set 7 | morro bay
# Processing Record 8 of Set 7 | new norfolk
# Processing Record 9 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 7 | mocuba
# Processing Record 11 of Set 7 | abha
# Processing Record 12 of Set 7 | dongsheng
# Processing Record 13 of Set 7 | saint george
# Processing Record 14 of Set 7 | salo
# Processing Record 15 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 16 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 17 of Set 7 | quang ngai
# Processing Record 18 of Set 7 | grand-santi
# Processing Record 19 of Set 7 | vardo
# Processing Record 20 of Set 7 | udachnyy
# Processing Record 21 of Set 7 | binzhou
# Processing Record 22 of Set 7 | hambantota
# Processing Record 23 of Set 7 | ono
# Processing Record 24 of Set 7 | hualmay
# Processing Record 25 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 26 of Set 7 | bend
# Processing Record 27 of Set 7 | qasigiannguit
# Processing Record 28 of Set 7 | bullas
# Processing Record 29 of Set 7 | kyzyl-suu
# Processing Record 30 of Set 7 | liepaja
# Processing Record 31 of Set 7 | acarau
# Processing Record 32 of Set 7 | shimoda
# Processing Record 33 of Set 7 | le port
# Processing Record 34 of Set 7 | nhulunbuy
# Processing Record 35 of Set 7 | jinchang
# Processing Record 36 of Set 7 | vostok
# Processing Record 37 of Set 7 | ostrovnoy
# Processing Record 38 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 39 of Set 7 | bonavista
# Processing Record 40 of Set 7 | cacador
# Processing Record 41 of Set 7 | eureka
# Processing Record 42 of Set 7 | honningsvag
# Processing Record 43 of Set 7 | campbellsville
# Processing Record 44 of Set 7 | kerrobert
# Processing Record 45 of Set 7 | andradina
# Processing Record 46 of Set 7 | yumen
# Processing Record 47 of Set 7 | umm lajj
# Processing Record 48 of Set 7 | nokaneng
# Processing Record 49 of Set 7 | katherine
# Processing Record 50 of Set 7 | matam
# Processing Record 1 of Set 8 | zhezkazgan
# Processing Record 2 of Set 8 | ostersund
# Processing Record 3 of Set 8 | prince rupert
# Processing Record 4 of Set 8 | pandan
# Processing Record 5 of Set 8 | thompson
# Processing Record 6 of Set 8 | junin
# Processing Record 7 of Set 8 | kilindoni
# Processing Record 8 of Set 8 | khorixas
# Processing Record 9 of Set 8 | pacific grove
# Processing Record 10 of Set 8 | richmond hill
# Processing Record 11 of Set 8 | samarai
# Processing Record 12 of Set 8 | oistins
# Processing Record 13 of Set 8 | yanam
# Processing Record 14 of Set 8 | greenfield
# Processing Record 15 of Set 8 | raudeberg
# Processing Record 16 of Set 8 | alyangula
# Processing Record 17 of Set 8 | arraial do cabo
# Processing Record 18 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 8 | sao gabriel da cachoeira
# Processing Record 20 of Set 8 | nimaparha
# Processing Record 21 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 8 | namatanai
# Processing Record 23 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 25 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 8 | villarrica
# Processing Record 27 of Set 8 | coihaique
# Processing Record 28 of Set 8 | dongkan
# Processing Record 29 of Set 8 | lebedinyy
# Processing Record 30 of Set 8 | kahului
# Processing Record 31 of Set 8 | fairbanks
# Processing Record 32 of Set 8 | kavos
# Processing Record 33 of Set 8 | burnie
# Processing Record 34 of Set 8 | visby
# Processing Record 35 of Set 8 | lagoa
# Processing Record 36 of Set 8 | san-pedro
# Processing Record 37 of Set 8 | tandil
# Processing Record 38 of Set 8 | belsand
# Processing Record 39 of Set 8 | oyugis
# Processing Record 40 of Set 8 | surenavan
# Processing Record 41 of Set 8 | gbarnga
# Processing Record 42 of Set 8 | loralai
# Processing Record 43 of Set 8 | lixourion
# Processing Record 44 of Set 8 | shkotovo-26
# City not found. Skipping...
# Processing Record 45 of Set 8 | angra
# City not found. Skipping...
# Processing Record 46 of Set 8 | verkh-usugli
# Processing Record 47 of Set 8 | ponta delgada
# Processing Record 48 of Set 8 | elliot lake
# Processing Record 49 of Set 8 | beyneu
# Processing Record 50 of Set 8 | walvis bay
# Processing Record 1 of Set 9 | reconquista
# Processing Record 2 of Set 9 | karabash
# Processing Record 3 of Set 9 | ruteng
# Processing Record 4 of Set 9 | poum
# Processing Record 5 of Set 9 | panguna
# Processing Record 6 of Set 9 | yuxia
# Processing Record 7 of Set 9 | kaitangata
# Processing Record 8 of Set 9 | cairns
# Processing Record 9 of Set 9 | praia da vitoria
# Processing Record 10 of Set 9 | faanui
# Processing Record 11 of Set 9 | alto araguaia
# Processing Record 12 of Set 9 | point fortin
# Processing Record 13 of Set 9 | aykhal
# Processing Record 14 of Set 9 | taranagar
# Processing Record 15 of Set 9 | torbay
# Processing Record 16 of Set 9 | inuvik
# Processing Record 17 of Set 9 | vitim
# Processing Record 18 of Set 9 | sunamganj
# City not found. Skipping...
# Processing Record 19 of Set 9 | bilma
# Processing Record 20 of Set 9 | hobyo
# Processing Record 21 of Set 9 | lappeenranta
# Processing Record 22 of Set 9 | kachug
# Processing Record 23 of Set 9 | san luis
# Processing Record 24 of Set 9 | duz
# City not found. Skipping...
# Processing Record 25 of Set 9 | sarahan
# Processing Record 26 of Set 9 | phu ly
# Processing Record 27 of Set 9 | kwinana
# Processing Record 28 of Set 9 | brazzaville
# Processing Record 29 of Set 9 | kholodnyy
# Processing Record 30 of Set 9 | porto belo
# Processing Record 31 of Set 9 | goderich
# Processing Record 32 of Set 9 | dunedin
# Processing Record 33 of Set 9 | north bend
# Processing Record 34 of Set 9 | coatepec harinas
# Processing Record 35 of Set 9 | saryagash
# Processing Record 36 of Set 9 | seguela
# Processing Record 37 of Set 9 | nandi
# Processing Record 38 of Set 9 | sur
# Processing Record 39 of Set 9 | kailua
# Processing Record 40 of Set 9 | kulhudhuffushi
# Processing Record 41 of Set 9 | itaituba
# Processing Record 42 of Set 9 | buchanan
# Processing Record 43 of Set 9 | byron bay
# Processing Record 44 of Set 9 | carutapera
# Processing Record 45 of Set 9 | jiangyou
# Processing Record 46 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 9 | painesville
# Processing Record 48 of Set 9 | nadym
# Processing Record 49 of Set 9 | san patricio
# Processing Record 50 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 10 | tolaga bay
# Processing Record 2 of Set 10 | culaman
# Processing Record 3 of Set 10 | krasnoselkup
# Processing Record 4 of Set 10 | san carlos de bariloche
# Processing Record 5 of Set 10 | kotelnikovo
# Processing Record 6 of Set 10 | olinda
# Processing Record 7 of Set 10 | sulangan
# Processing Record 8 of Set 10 | olivet
# Processing Record 9 of Set 10 | chimbote
# Processing Record 10 of Set 10 | bac lieu
# Processing Record 11 of Set 10 | lavrentiya
# Processing Record 12 of Set 10 | nuevo laredo
# Processing Record 13 of Set 10 | te anau
# Processing Record 14 of Set 10 | the valley
# Processing Record 15 of Set 10 | novikovo
# Processing Record 16 of Set 10 | tuatapere
# Processing Record 17 of Set 10 | petukhovo
# Processing Record 18 of Set 10 | huanren
# Processing Record 19 of Set 10 | los llanos de aridane
# Processing Record 20 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 10 | lata
# Processing Record 22 of Set 10 | cartagena
# Processing Record 23 of Set 10 | plettenberg bay
# Processing Record 24 of Set 10 | lubumbashi
# Processing Record 25 of Set 10 | havelock
# Processing Record 26 of Set 10 | pyay
# Processing Record 27 of Set 10 | opuwo
# Processing Record 28 of Set 10 | damietta
# Processing Record 29 of Set 10 | broome
# Processing Record 30 of Set 10 | meulaboh
# Processing Record 31 of Set 10 | westport
# Processing Record 32 of Set 10 | kavaratti
# Processing Record 33 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 34 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 10 | naples
# Processing Record 36 of Set 10 | mikuni
# Processing Record 37 of Set 10 | saint-georges
# Processing Record 38 of Set 10 | bucerias
# Processing Record 39 of Set 10 | ambulu
# Processing Record 40 of Set 10 | waddan
# Processing Record 41 of Set 10 | seoul
# Processing Record 42 of Set 10 | ucluelet
# Processing Record 43 of Set 10 | carauari
# Processing Record 44 of Set 10 | angoram
# Processing Record 45 of Set 10 | nkhotakota
# Processing Record 46 of Set 10 | tasiilaq
# Processing Record 47 of Set 10 | whyalla
# Processing Record 48 of Set 10 | mehamn
# Processing Record 49 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 10 | manaus
# Processing Record 1 of Set 11 | vyazemskiy
# Processing Record 2 of Set 11 | herzberg
# Processing Record 3 of Set 11 | salalah
# Processing Record 4 of Set 11 | esperance
# Processing Record 5 of Set 11 | ardabil
# Processing Record 6 of Set 11 | adrar
# Processing Record 7 of Set 11 | yurimaguas
# Processing Record 8 of Set 11 | nemuro
# Processing Record 9 of Set 11 | palmer
# Processing Record 10 of Set 11 | vrangel
# Processing Record 11 of Set 11 | misratah
# Processing Record 12 of Set 11 | tapa
# Processing Record 13 of Set 11 | roald
# Processing Record 14 of Set 11 | ghatanji
# Processing Record 15 of Set 11 | nador
# Processing Record 16 of Set 11 | olafsvik
# Processing Record 17 of Set 11 | baykalsk
# Processing Record 18 of Set 11 | dombarovskiy
# Processing Record 19 of Set 11 | erzin
# Processing Record 20 of Set 11 | talaya
# Processing Record 21 of Set 11 | tocache
# Processing Record 22 of Set 11 | teguise
# Processing Record 23 of Set 11 | hirado
# Processing Record 24 of Set 11 | madang
# Processing Record 25 of Set 11 | hofn
# Processing Record 26 of Set 11 | uniao
# Processing Record 27 of Set 11 | auki
# Processing Record 28 of Set 11 | constitucion
# Processing Record 29 of Set 11 | biltine
# Processing Record 30 of Set 11 | ocotepec
# Processing Record 31 of Set 11 | morbegno
# Processing Record 32 of Set 11 | lubango
# Processing Record 33 of Set 11 | berlevag
# Processing Record 34 of Set 11 | corinto
# Processing Record 35 of Set 11 | karratha
# Processing Record 36 of Set 11 | ayios kirikos
# City not found. Skipping...
# Processing Record 37 of Set 11 | agirish
# Processing Record 38 of Set 11 | vao
# Processing Record 39 of Set 11 | dekoa
# City not found. Skipping...
# Processing Record 40 of Set 11 | san cristobal
# Processing Record 41 of Set 11 | muscatine
# Processing Record 42 of Set 11 | shahrud
# Processing Record 43 of Set 11 | krasnyy chikoy
# Processing Record 44 of Set 11 | gigmoto
# Processing Record 45 of Set 11 | mackenzie
# Processing Record 46 of Set 11 | katobu
# Processing Record 47 of Set 11 | kharhial
# Processing Record 48 of Set 11 | sakakah
# Processing Record 49 of Set 11 | sainte-anne-des-monts
# Processing Record 50 of Set 11 | port moresby
# Processing Record 1 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 12 | waw
# Processing Record 3 of Set 12 | hede
# Processing Record 4 of Set 12 | marzuq
# Processing Record 5 of Set 12 | pearl
# Processing Record 6 of Set 12 | correntina
# Processing Record 7 of Set 12 | curup
# Processing Record 8 of Set 12 | sorland
# Processing Record 9 of Set 12 | kaseda
# Processing Record 10 of Set 12 | san pedro
# Processing Record 11 of Set 12 | bereda
# Processing Record 12 of Set 12 | pietarsaari
# Processing Record 13 of Set 12 | tecoanapa
# Processing Record 14 of Set 12 | nizwa
# Processing Record 15 of Set 12 | kaka
# Processing Record 16 of Set 12 | arman
# Processing Record 17 of Set 12 | sarai sidhu
# Processing Record 18 of Set 12 | tilichiki
# Processing Record 19 of Set 12 | pundaguitan
# Processing Record 20 of Set 12 | kangalassy
# Processing Record 21 of Set 12 | muroto
# Processing Record 22 of Set 12 | otradnoye
# Processing Record 23 of Set 12 | ayagoz
# Processing Record 24 of Set 12 | isabela
# Processing Record 25 of Set 12 | klaksvik
# Processing Record 26 of Set 12 | okhotsk
# Processing Record 27 of Set 12 | port-gentil
# Processing Record 28 of Set 12 | winneba
# Processing Record 29 of Set 12 | arucas
# Processing Record 30 of Set 12 | goias
# Processing Record 31 of Set 12 | ejido
# Processing Record 32 of Set 12 | cabedelo
# Processing Record 33 of Set 12 | vilhena
# Processing Record 34 of Set 12 | manaure
# Processing Record 35 of Set 12 | melo
# Processing Record 36 of Set 12 | sao paulo de olivenca
# Processing Record 37 of Set 12 | richards bay
# Processing Record 38 of Set 12 | cap-aux-meules
# Processing Record 39 of Set 12 | logan
# Processing Record 40 of Set 12 | alice springs
# Processing Record 41 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 12 | limon
# Processing Record 43 of Set 12 | thiruvananthapuram
# Processing Record 44 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 12 | chapais
# Processing Record 46 of Set 12 | nome
# Processing Record 47 of Set 12 | atambua
# Processing Record 48 of Set 12 | haines junction
# Processing Record 49 of Set 12 | meadow lake
# Processing Record 50 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 13 | katghora
# Processing Record 2 of Set 13 | okha
# Processing Record 3 of Set 13 | bodden town
# Processing Record 4 of Set 13 | marakkanam
# Processing Record 5 of Set 13 | wucheng
# Processing Record 6 of Set 13 | sovetskiy
# Processing Record 7 of Set 13 | nishihara
# Processing Record 8 of Set 13 | saint-augustin
# Processing Record 9 of Set 13 | acu
# Processing Record 10 of Set 13 | freeport
# Processing Record 11 of Set 13 | pisco
# Processing Record 12 of Set 13 | porto seguro
# Processing Record 13 of Set 13 | basco
# Processing Record 14 of Set 13 | mantua
# Processing Record 15 of Set 13 | taquaritinga
# Processing Record 16 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 13 | parana
# Processing Record 18 of Set 13 | marsh harbour
# Processing Record 19 of Set 13 | requena
# Processing Record 20 of Set 13 | balad
# Processing Record 21 of Set 13 | bima
# Processing Record 22 of Set 13 | sistranda
# Processing Record 23 of Set 13 | moree
# Processing Record 24 of Set 13 | sidney
# Processing Record 25 of Set 13 | wagar
# Processing Record 26 of Set 13 | ballina
# Processing Record 27 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 13 | gat
# Processing Record 29 of Set 13 | vanimo
# Processing Record 30 of Set 13 | gao
# Processing Record 31 of Set 13 | alta floresta
# Processing Record 32 of Set 13 | sept-iles
# Processing Record 33 of Set 13 | polewali
# Processing Record 34 of Set 13 | cabras
# Processing Record 35 of Set 13 | chingirlau
# Processing Record 36 of Set 13 | dourados
# Processing Record 37 of Set 13 | estacion coahuila
# Processing Record 38 of Set 13 | porto novo
# Processing Record 39 of Set 13 | pokhara
# Processing Record 40 of Set 13 | putina
# Processing Record 41 of Set 13 | coquimbo
# Processing Record 42 of Set 13 | labuhan
# Processing Record 43 of Set 13 | lakes entrance
# Processing Record 44 of Set 13 | almaznyy
# Processing Record 45 of Set 13 | killybegs
# Processing Record 46 of Set 13 | huaihua
# Processing Record 47 of Set 13 | trelew
# Processing Record 48 of Set 13 | kanigoro
# Processing Record 49 of Set 13 | russkaya polyana
# Processing Record 50 of Set 13 | boyolangu
# Processing Record 1 of Set 14 | ivdel
# Processing Record 2 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 14 | montepuez
# Processing Record 4 of Set 14 | iwanai
# Processing Record 5 of Set 14 | cockburn town
# Processing Record 6 of Set 14 | saint-pierre
# Processing Record 7 of Set 14 | ifo
# Processing Record 8 of Set 14 | barcelona
# Processing Record 9 of Set 14 | micheweni
# Processing Record 10 of Set 14 | balkanabat
# Processing Record 11 of Set 14 | myitkyina
# Processing Record 12 of Set 14 | boa vista
# Processing Record 13 of Set 14 | sosnovo-ozerskoye
# Processing Record 14 of Set 14 | chinsali
# Processing Record 15 of Set 14 | kaifeng
# Processing Record 16 of Set 14 | nantucket
# Processing Record 17 of Set 14 | banepa
# Processing Record 18 of Set 14 | damascus
# Processing Record 19 of Set 14 | waingapu
# Processing Record 20 of Set 14 | cabo san lucas
# Processing Record 21 of Set 14 | jalu
# Processing Record 22 of Set 14 | bay roberts
# Processing Record 23 of Set 14 | turochak
# Processing Record 24 of Set 14 | omboue
# Processing Record 25 of Set 14 | sorong
# Processing Record 26 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 27 of Set 14 | worland
# Processing Record 28 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 29 of Set 14 | henties bay
# Processing Record 30 of Set 14 | linqiong
# Processing Record 31 of Set 14 | leh
# Processing Record 32 of Set 14 | north myrtle beach
# Processing Record 33 of Set 14 | kandrian
# Processing Record 34 of Set 14 | rundu
# Processing Record 35 of Set 14 | itumbiara
# Processing Record 36 of Set 14 | shubarkuduk
# Processing Record 37 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 38 of Set 14 | fort nelson
# Processing Record 39 of Set 14 | luebo
# Processing Record 40 of Set 14 | nakambala
# Processing Record 41 of Set 14 | bolotnoye
# Processing Record 42 of Set 14 | saint-francois
# Processing Record 43 of Set 14 | qostanay
# Processing Record 44 of Set 14 | conde
# Processing Record 45 of Set 14 | qaqortoq
# Processing Record 46 of Set 14 | la libertad
# Processing Record 47 of Set 14 | muravlenko
# Processing Record 48 of Set 14 | shuangcheng
# Processing Record 49 of Set 14 | verkhnyaya toyma
# Processing Record 50 of Set 14 | noshiro
# Processing Record 1 of Set 15 | aklavik
# Processing Record 2 of Set 15 | talara
# Processing Record 3 of Set 15 | juneau
# Processing Record 4 of Set 15 | moura
# Processing Record 5 of Set 15 | storforshei
# Processing Record 6 of Set 15 | darhan
# Processing Record 7 of Set 15 | altea
# Processing Record 8 of Set 15 | kununurra
# Processing Record 9 of Set 15 | matara
# Processing Record 10 of Set 15 | tiznit
# Processing Record 11 of Set 15 | mogadishu
# Processing Record 12 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 15 | xichang
# Processing Record 14 of Set 15 | tautira
# Processing Record 15 of Set 15 | bubaque
# Processing Record 16 of Set 15 | sazonovo
# Processing Record 17 of Set 15 | nenjiang
# Processing Record 18 of Set 15 | dhidhdhoo
# Processing Record 19 of Set 15 | vanderhoof
# Processing Record 20 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 15 | bosaso
# Processing Record 22 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 23 of Set 15 | ugoofaaru
# Processing Record 24 of Set 15 | fort saint james
# Processing Record 25 of Set 15 | ylivieska
# Processing Record 26 of Set 15 | shenjiamen
# Processing Record 27 of Set 15 | soyo
# Processing Record 28 of Set 15 | yar-sale
# Processing Record 29 of Set 15 | santa maria
# Processing Record 30 of Set 15 | birao
# Processing Record 31 of Set 15 | takapau
# Processing Record 32 of Set 15 | saint-leu
# Processing Record 33 of Set 15 | burica
# City not found. Skipping...
# Processing Record 34 of Set 15 | cortes
# Processing Record 35 of Set 15 | husavik
# Processing Record 36 of Set 15 | carballo
# Processing Record 37 of Set 15 | taksimo
# Processing Record 38 of Set 15 | bloemfontein
# Processing Record 39 of Set 15 | sobolevo
# Processing Record 40 of Set 15 | swan hill
# Processing Record 41 of Set 15 | bilibino
# Processing Record 42 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 43 of Set 15 | san borja
# Processing Record 44 of Set 15 | gouyave
# Processing Record 45 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 15 | parli
# Processing Record 47 of Set 15 | vallenar
# Processing Record 48 of Set 15 | yurla
# Processing Record 49 of Set 15 | stokmarknes
# Processing Record 50 of Set 15 | suao
# City not found. Skipping...
# Processing Record 1 of Set 16 | ambon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Panda DataFrame. 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hobart -42.8794  147.3294     62.02        67          75
# 1          Mataura -46.1927  168.8643     66.36        63         100
# 2  Bambous Virieux -20.3428   57.7575     77.25        94          75
# 3            Bluff -46.6000  168.3333     63.68        76         100
# 4           Tshela  -4.9833   12.9333     72.59       100         100
# 5          Peniche  39.3558   -9.3811     52.09        60         100
# 6          Rikitea -23.1203 -134.9692     78.33        64          46
# 7      Brownsville  25.9018  -97.4975     78.75        84         100
# 8            Kapaa  22.0752 -159.3190     80.58        72          40
# 9              Pyu  18.4833   96.4333     88.56        40          12
#
#    Wind Speed Country Current Description
# 0       13.80      AU       broken clouds
# 1        2.33      NZ          light rain
# 2       10.36      MU       broken clouds
# 3        7.07      NZ     overcast clouds
# 4        0.36      CD     overcast clouds
# 5       13.38      PT     overcast clouds
# 6       11.54      PF    scattered clouds
# 7       14.97      US                haze
# 8       13.80      US    scattered clouds
# 9        2.75      MM          few clouds

# %%
city_data_order=["City","Country","Lat","Lng", "Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[city_data_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hobart      AU -42.8794  147.3294     62.02        67          75
# 1          Mataura      NZ -46.1927  168.8643     66.36        63         100
# 2  Bambous Virieux      MU -20.3428   57.7575     77.25        94          75
# 3            Bluff      NZ -46.6000  168.3333     63.68        76         100
# 4           Tshela      CD  -4.9833   12.9333     72.59       100         100
# 5          Peniche      PT  39.3558   -9.3811     52.09        60         100
# 6          Rikitea      PF -23.1203 -134.9692     78.33        64          46
# 7      Brownsville      US  25.9018  -97.4975     78.75        84         100
# 8            Kapaa      US  22.0752 -159.3190     80.58        72          40
# 9              Pyu      MM  18.4833   96.4333     88.56        40          12
#
#    Wind Speed Current Description
# 0       13.80       broken clouds
# 1        2.33          light rain
# 2       10.36       broken clouds
# 3        7.07     overcast clouds
# 4        0.36     overcast clouds
# 5       13.38     overcast clouds
# 6       11.54    scattered clouds
# 7       14.97                haze
# 8       13.80    scattered clouds
# 9        2.75          few clouds

# %%
# Create the output file (CSV).

output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_data into a CSV.

city_data_df.to_csv(output_data_file, index_label='City_ID')
